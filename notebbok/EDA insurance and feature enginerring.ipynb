# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
#      ---------------------------------------- 0.0/68.3 kB ? eta -:--:--
#      ---------------------------------------- 68.3/68.3 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from kagglehub) (6.0.1)
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: packaging in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from kagglehub) (23.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->kagglehub) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->kagglehub) (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->kagglehub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: colorama in c:\users\sunny\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm->kagglehub) (0.4.6)
# Installing collected packages: tqdm, kagglehub
# Successfully installed kagglehub-0.3.13 tqdm-4.67.1
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: C:\Users\Sunny\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mosapabdelghany/medical-insurance-cost-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mosapabdelghany/medical-insurance-cost-dataset?dataset_version_number=1...
# 100%|██████████| 16.0k/16.0k [00:00<00:00, 36.7MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Sunny\.cache\kagglehub\datasets\mosapabdelghany\medical-insurance-cost-dataset\versions\1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os

# %%
print(os.listdir(path))
# Out:
# ['insurance.csv']

# %%
df =pd.read_csv(path+"/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# create visuliazatiojn of distribution of charges, smkoing , BMI, age ,children and region.
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.ravel()

sns.histplot(df['charges'], kde=True, ax=axes[0])
axes[0].set_title('Distribution of Charges')

sns.histplot(df['bmi'], kde=True, ax=axes[1])
axes[1].set_title('Distribution of BMI')

sns.histplot(df['age'], kde=True, ax=axes[2])
axes[2].set_title('Distribution of Age')

sns.countplot(x='children', data=df, ax=axes[3])
axes[3].set_title('Distribution of Children')

sns.countplot(x='smoker', data=df, ax=axes[4])
axes[4].set_title('Smoker Count')

# If you don't need the 6th subplot, turn it off
axes[5].axis('off')

plt.tight_layout(pad=2.0)
plt.subplots_adjust(top=0.92)

# %% [markdown]
# There are five key insights from this dataset:
#
# Insurance charges are left-skewed, with the majority of costs ranging from $200 to $1,200.
#
# BMI follows a bell-shaped curve, indicating a normal distribution, with both the median and mode centered at 30.
#
# Age distribution shows that clients in their early 20s represent the largest group of insurance subscribers, while the remaining ages are distributed more uniformly.
#
# Number of children exhibits a significant negative correlation with insurance subscribe.
#
# There is a notable class imbalance between non-smokers and smokers.

# %%
# charge group by smoker
smoker_group = df.groupby('smoker')['charges']
smoker_stats = smoker_group.describe()
print(smoker_stats)
# Out:
#          count          mean           std         min           25%  \
# smoker
# no      1064.0   8434.268298   5993.781819   1121.8739   3986.438700
# yes      274.0  32050.231832  11541.547176  12829.4551  20826.244213
#
#                 50%           75%          max
# smoker
# no       7345.40530  11362.887050  36910.60803
# yes     34456.34845  41019.207275  63770.42801

# %%
# create visulization between BMI and charges for smoker and non smokers
plt.figure(figsize=(10, 6))
sns.scatterplot(x='bmi', y='charges', hue='smoker', data=df)
plt.title('Charges vs BMI by Smoking Status')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.legend(title='Smoker')
plt.show()

# %% [markdown]
# There is no signifficant difeerence in BMI between smokers and non-smokers, but smokers tend to have significantly higher insurance charges compared to non-smokers. This suggests that smoking status has a more pronounced impact on insurance costs than BMI alone.

# %%
# perform t-test to see if there is a significant difference in charges between smokers and non-smokers
from scipy import stats
smoker_charges = df[df['smoker'] == 'yes']['charges']
non_smoker_charges = df[df['smoker'] == 'no']['charges']
t_stat, p_value = stats.ttest_ind(smoker_charges, non_smoker_charges)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
if p_value < 0.05:
    print("There is a significant difference in charges between smokers and non-smokers.")
else:
    print("There is no significant difference in charges between smokers and non-smokers.")
# Out:
# T-statistic: 46.66492117272371, P-value: 8.271435842179102e-283
# There is a significant difference in charges between smokers and non-smokers.
